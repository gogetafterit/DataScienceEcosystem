# %% [markdown]
# # 📝 Data Science Tools and Ecosystem
#
# **Author:** Your Name
# **Course:** IBM Data Science Professional Certificate
# **Date:** 2025-09-26
# ---
# Welcome to this notebook! This notebook summarizes the Data Science tools and ecosystem, and demonstrates the requested exercises step by step.
#
# ![Data Science](https://raw.githubusercontent.com/username/repo/main/images/data_science.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %%
print("Data Science Tools and Ecosystem")
# Out:
# Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %%
print(
    "In this notebook, Data Science Tools and Ecosystem are summarized.\n\n"
    "We build the twelve requested pieces step-by-step:\n"
    " 1  Title & intro\n"
    " 2  Languages list\n"
    " 3  Libraries list\n"
    " 4  Tool table\n"
    " 5  Two Python calculations\n"
    " 6  Objectives & author\n"
    " 7  Push to GitHub\n"
    "—exactly as specified in the final peer-graded assignment."
)
# Out:
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# We build the twelve requested pieces step-by-step:
#  1  Title & intro
#  2  Languages list
#  3  Libraries list
#  4  Tool table
#  5  Two Python calculations
#  6  Objectives & author
#  7  Push to GitHub
# —exactly as specified in the final peer-graded assignment.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. MATLAB
# 7. Java
# 8. JavaScript/TypeScript
# 9. SAS
# 10. Go

# %%
languages = [
    "Python",
    "R",
    "SQL",
    "Julia",
    "Scala",
    "MATLAB",
    "Java",
    "JavaScript/TypeScript",
    "SAS",
    "Go"
]

print("Some of the popular languages that Data Scientists use are:")
for i, lang in enumerate(languages, start=1):
    print(f"{i}. {lang}")
# Out:
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. MATLAB
# 7. Java
# 8. JavaScript/TypeScript
# 9. SAS
# 10. Go

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. pandas
# 3. scikit-learn
# 4. Matplotlib
# 5. Seaborn
# 6. TensorFlow
# 7. PyTorch
# 8. XGBoost
# 9. Statsmodels
# 10. Plotly

# %%
libraries = [
    "NumPy",
    "pandas",
    "scikit-learn",
    "Matplotlib",
    "Seaborn",
    "TensorFlow",
    "PyTorch",
    "XGBoost",
    "Statsmodels",
    "Plotly"
]

print("Some of the commonly used libraries used by Data Scientists include:")
for i, lib in enumerate(libraries, start=1):
    print(f"{i}. {lib}")
# Out:
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. pandas
# 3. scikit-learn
# 4. Matplotlib
# 5. Seaborn
# 6. TensorFlow
# 7. PyTorch
# 8. XGBoost
# 9. Statsmodels
# 10. Plotly

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | JupyterLab         |
# | RStudio            |
# | VS Code            |

# %%
print("Data Science Tools")
print("------------------")
print("JupyterLab")
print("RStudio")
print("VS Code")
# Out:
# Data Science Tools
# ------------------
# JupyterLab
# RStudio
# VS Code

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
print("Expression | Result")
print("-----------|-------")
print("2 + 3      |", 2 + 3)
print("10 - 4     |", 10 - 4)
print("3 * 7      |", 3 * 7)
print("15 / 3     |", 15 / 3)
print("2 ** 4     |", 2 ** 4)
# Out:
# Expression | Result
# -----------|-------
# 2 + 3      | 5
# 10 - 4     | 6
# 3 * 7      | 21
# 15 / 3     | 5.0
# 2 ** 4     | 16

# %% [markdown]
# # This is a simple arithmetic expression to multiply then add integers
# (3 * 4) + 5

# %%
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# # This will convert 200 minutes to hours by dividing by 60
# 200 / 60

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - Demonstrate basic Python arithmetic operations
# - Convert units (minutes to hours)
# - Insert and format markdown cells
# - Run code cells and capture outputs

# %%
from IPython.display import Markdown, display

display(Markdown("""**Objectives:**

- List popular languages for Data Science
- Introduce commonly used libraries
- Create tables with Data Science tools
- Demonstrate arithmetic expressions
- Convert minutes to hours"""))
# Out:
# **Objectives:**
#
# - List popular languages for Data Science
# - Introduce commonly used libraries
# - Create tables with Data Science tools
# - Demonstrate arithmetic expressions
# - Convert minutes to hours

# %% [markdown]
# ## Author.
# S. Manuel P.

# %%
# Exercise 11
from IPython.display import Markdown, display

display(Markdown("""## Author.
S. Manuel P. """))
# Out:
# ## Author.
# S. Manuel P.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install PyGithub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.0 MB/s eta 0:00:00
# ...

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'Copy of A_01_Network_Anomaly_Detection_Project.ipynb'
# 'DataScienceEcosystem(1).ipynb'
#  DataScienceEcosystem.ipynb
#  Untitled0.ipynb

# %%
import os
from github import Github, Auth

# [REMOVED SECRET]token = os.environ.get("GITHUB_TOKEN")
g = Github(auth=Auth.Token(token))

# %%
from github import Github, Auth
from google.colab import drive
import os
import json

drive.mount('/content/drive', force_remount=True)

# [REMOVED SECRET]token = os.environ.get("GITHUB_TOKEN")
repo_name = "gogetafterit/DataScienceEcosystem"
branch_name = "main"

file_path = "/content/drive/MyDrive/Colab Notebooks/DataScienceEcosystem.ipynb"
if not os.path.exists(file_path):
    raise FileNotFoundError(f"No se encontró el archivo: {file_path}")

commit_message = "Add or update datascience ecosystem notebook"

with open(file_path, "r", encoding="utf-8") as f:
    notebook = json.load(f)

# Buscar y reemplazar cualquier token en las celdas de código
for cell in notebook.get("cells", []):
    if cell.get("cell_type") == "code":
        cell["source"] = [
# [REMOVED SECRET]            for line in cell.get("source", [])
        ]

# Convertir de nuevo a JSON para subirlo
content = json.dumps(notebook, ensure_ascii=False)

g = Github(auth=Auth.Token(token))
repo = g.get_repo(repo_name)

file_name_in_repo = "datascience_ecosystem.ipynb"  # Nombre en GitHub

try:
    # Intentar obtener el archivo en el repo
    existing_file = repo.get_contents(file_name_in_repo, ref=branch_name)
    # Si existe, actualizarlo
    repo.update_file(
        path=existing_file.path,
        message=commit_message,
        content=content,
        sha=existing_file.sha,
        branch=branch_name
    )
    print(f" File '{file_name_in_repo}' updated successfully in GitHub!")

except Exception as e:
    # Si no existe, crearlo
    repo.create_file(
        path=file_name_in_repo,
        message=commit_message,
        content=content,
        branch=branch_name
    )
    print(f" File '{file_name_in_repo}' created successfully in GitHub!")
# Out:
# Mounted at /content/drive
#  File 'datascience_ecosystem.ipynb' updated successfully in GitHub!

# %%
readme_content = (
    "In this notebook, Data Science Tools and Ecosystem are summarized.\n\n"
    "We build the twelve requested pieces step-by-step:\n"
    " 1  Title & intro\n"
    " 2  Languages list\n"
    " 3  Libraries list\n"
    " 4  Tool table\n"
    " 5  Two Python calculations\n"
    " 6  Objectives & author\n"
    " 7  Push to GitHub\n"
    ", exactly as specified in the final peer-graded assignment."
)

readme_file = "README.md"

try:
    # Try to get existing README
    existing_readme = repo.get_contents(readme_file, ref=branch_name)
    repo.update_file(
        path=readme_file,
        message="Update README with assignment description",
        content=readme_content,
        sha=existing_readme.sha,
        branch=branch_name
    )
    print(" README.md updated successfully!")

except Exception as e:
    # If README does not exist, create it
    repo.create_file(
        path=readme_file,
        message="Create README with assignment description",
        content=readme_content,
        branch=branch_name
    )
    print(" README.md created successfully!")
# Out:
#  README.md updated successfully!
